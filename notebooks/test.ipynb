# %%
from scipy.spatial.transform import Rotation
import numpy as np
from matplotlib import pyplot as plt

# %%
y2z = [[0, 0, 1], [1, 0, 0], [0, 1, 0]]


R = Rotation.from_matrix(y2z)

# %%
import numpy as np
import matplotlib.pyplot as plt

old_axes = np.eye(3)
new_axes = R.apply(np.eye(3))

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")

origin = np.zeros(3)

colors = ["r", "g", "b"]
labels = ["X", "Y", "Z"]

# 原始坐标系 eye(3)
for vec, color, label in zip(old_axes, colors, labels):
    ax.quiver(
        origin[0], origin[1], origin[2],
        vec[0], vec[1], vec[2],
        color=color,
        alpha=0.25,
        linestyle="dashed",
        length=1.0,
        normalize=False,
        label=f"original {label}",
    )

# 旋转后的坐标系 R.apply(eye(3))
for vec, color, label in zip(new_axes, colors, labels):
    ax.quiver(
        origin[0], origin[1], origin[2],
        vec[0], vec[1], vec[2],
        color=color,
        linewidth=2.5,
        length=1.0,
        normalize=False,
        label=f"rotated {label}",
    )

ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_zlim([-1, 1])

ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
ax.set_box_aspect([1, 1, 1])
ax.legend()

plt.show()
